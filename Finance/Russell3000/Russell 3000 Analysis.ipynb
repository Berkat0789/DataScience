# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as web

# %%
from yahoo_fin import options

# %%
options.get_options_chain("nflx")["puts"]
# Out:
#            Contract Name         Last Trade Date  Strike  Last Price  Bid  \
# 0    NFLX230721P00050000   2023-07-10 1:23PM EDT    50.0        0.01  0.0
# 1    NFLX230721P00060000   2023-07-05 9:30AM EDT    60.0        0.01  0.0
# 2    NFLX230721P00070000  2023-06-29 12:39PM EDT    70.0        0.01  0.0
# 3    NFLX230721P00080000   2023-06-16 3:17PM EDT    80.0        0.01  0.0
# 4    NFLX230721P00090000   2023-06-29 1:53PM EDT    90.0        0.01  0.0
# ..                   ...                     ...     ...         ...  ...
# 138  NFLX230721P00625000   2023-07-12 3:59PM EDT   625.0      180.96  0.0
# 139  NFLX230721P00630000   2023-07-12 3:59PM EDT   630.0      185.98  0.0
# 140  NFLX230721P00640000  2023-07-12 12:16PM EDT   640.0      201.50  0.0
# 141  NFLX230721P00650000  2023-07-12 12:16PM EDT   650.0      211.50  0.0
# 142  NFLX230721P00660000   2023-07-12 2:43PM EDT   660.0      216.38  0.0
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# ...

# %%
compaines = pd.read_excel("ru3000_membershiplist_20200629.xlsx")

# %%
tickers1 = list(compaines["Ticker"])

# %%
tickers2 = list(compaines["Ticker.1"])

# %%
tickers = tickers1 + tickers2

# %%
len(tickers)
# Out:
# 3036

# %%
sandp = pd.read_excel("SP-500-Companies-List.xlsx")

# %%
sAndPTickers = [x.split(",")[0] for x in sandp["Copy All Below Symbol and Paste In TradingView"]]

# %%
sAndPTickers
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'BRK.B',
#  'GOOGL',
#  'GOOG',
#  'XOM',
#  'UNH',
#  'JNJ',
#  'NVDA',
#  'JPM',
#  'V',
#  'PG',
#  'TSLA',
#  'HD',
#  'CVX',
#  'MA',
#  'META',
#  'LLY',
#  'MRK',
#  'ABBV',
#  'PFE',
#  'PEP',
#  'BAC',
#  'KO',
#  'AVGO',
#  'TMO',
#  'COST',
#  'WMT',
#  'MCD',
#  'ABT',
#  'CSCO',
#  'DIS',
#  'DHR',
#  'ACN',
#  'VZ',
#  'NEE',
#  'WFC',
#  'CMCSA',
#  'LIN',
#  'NKE',
#  'ADBE',
#  'TXN',
#  'PM',
#  'BMY',
#  'COP',
#  'CRM',
#  'NFLX',
#  'AMGN',
#  'RTX',
#  'HON',
#  'QCOM',
#  'T',
#  'ORCL',
#  'CAT',
#  'LOW',
#  'UNP',
#  'UPS',
#  'MS',
#  'IBM',
#  'SCHW',
#  'SPGI',
#  'SBUX',
#  'INTC',
#  'GS',
#  'BA',
#  'DE',
#  'CVS',
#  'AMD',
#  'PLD',
#  'ELV',
#  'BLK',
#  'INTU',
#  'GILD',
#  'AMT',
#  'MDT',
#  'LMT',
#  'ADP',
#  'C',
#  'AMAT',
#  'CI',
#  'TJX',
#  'CB',
#  'ISRG',
#  'AXP',
#  'BKNG',
#  'MDLZ',
#  'PYPL',
#  'TMUS',
#  'GE',
#  'ADI',
#  'SYK',
#  'MMC',
#  'NOW',
#  'SLB',
#  'VRTX',
#  'MO',
#  'DUK',
# ...

# %%
tickers = tickers + sAndPTickers

# %%
len(tickers)
# Out:
# 3539

# %%
df = pd.DataFrame()
for x in tickers: 
    df[x] = web.download(x, start = "2023-7-1")["Adj Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ONEM: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - FCCY: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df = df.dropna(axis=1)

# %%
len(df.columns)
# Out:
# 3009

# %%
pd.DataFrame(df.corrwith(df["NVDA"]).sort_values(ascending = False).head(100))
# Out:
#              0
# NVDA  1.000000
# PPC   0.979332
# AUB   0.979129
# INDB  0.978925
# WK    0.976863
# ...        ...
# ACIW  0.921265
# ACN   0.920851
# PROV  0.920537
# TBNK  0.920027
# ATRC  0.919953
#
# [100 rows x 1 columns]

# %%
corrWNVDA = list(pd.DataFrame(df.corrwith(df["NVEC"]).sort_values(ascending = False).head(100)).index)

# %%
itemsCoorelatedWithNVDA = df[corrWNVDA]

# %%
itemsCoorelatedWithNVDA[itemsCoorelatedWithNVDA < 5].dropna(axis=1)
# Out:
#             UIHC    NKTR   CMRX    OPK  LXRX   HBI  NSTG  SFIX  VERU    BDTX  \
# Date
# 2023-07-03  4.40  0.5700  1.190  2.130  2.32  4.80  3.96  4.23  1.20  4.6900
# 2023-07-05  4.23  0.5700  1.210  2.100  2.26  4.60  3.86  4.01  1.20  4.8600
# 2023-07-06  4.14  0.5500  1.150  2.060  2.22  4.54  3.57  3.76  1.11  4.4800
# 2023-07-07  3.96  0.5500  1.160  2.050  2.22  4.28  3.70  3.97  1.13  4.4100
# 2023-07-10  4.32  0.5700  1.230  2.110  2.33  4.53  4.40  4.24  1.20  4.6600
# 2023-07-11  4.41  0.5800  1.210  2.150  2.33  4.80  4.51  4.33  1.23  4.9900
# 2023-07-12  4.33  0.5700  1.210  2.150  2.31  4.69  4.54  4.29  1.23  4.9300
# 2023-07-13  4.30  0.5700  1.210  2.090  2.30  4.71  4.19  4.20  1.26  4.9050
# 2023-07-14  4.15  0.5500  1.190  2.090  2.21  4.47  3.92  4.00  1.22  4.8500
# 2023-07-17  4.14  0.5534  1.185  2.085  2.24  4.44  3.82  3.98  1.23  4.9899
#
#             GRWG      LL
# Date
# 2023-07-03  3.59  3.8300
# 2023-07-05  3.40  3.6700
# 2023-07-06  3.26  3.5500
# ...

# %%
corrWApple = list(pd.DataFrame(df.corrwith(df["AAPL"]).sort_values(ascending = False).head(100)).index)

# %%
itemsCoorelatedWithApple = df[corrWApple]

# %%
itemsCoorelatedWithApple[itemsCoorelatedWithApple < 50].dropna(axis=1)
# Out:
#                  AQUA       CWEN        TGH       HWKN        KDP        CSX  \
# Date
# 2020-01-02  18.910000  18.203524  10.495541  21.697355  27.559219  23.347221
# 2020-01-03  19.100000  18.167210  10.416700  21.091368  27.626345  23.251526
# 2020-01-06  18.469999  18.221680  10.367427  20.973005  27.808538  23.130310
# 2020-01-07  18.450001  18.139971  10.594090  20.698416  27.041405  23.286615
# 2020-01-08  18.450001  18.339714  10.584235  20.570591  26.619484  23.407829
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-23  39.840000  31.980000  31.020000  38.923019  36.369999  31.027040
# 2022-12-27  40.000000  32.040001  31.190001  39.071999  36.099998  31.017113
# 2022-12-28  39.189999  31.580000  30.809999  38.019218  35.770000  30.619965
# 2022-12-29  40.410000  31.940001  31.350000  38.764107  35.830002  31.017113
# 2022-12-30  39.599998  31.870001  31.010000  38.337040  35.660000  30.758965
#
# ...

# %%
df = df[set(df.columns)]

# %%
itemsCoorelatedWithApple[itemsCoorelatedWithApple < 30].dropna(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.to_csv("WOrkingListDdf.csv")

# %% [markdown]
# ## Daily Returns

# %%
returnsDf = pd.DataFrame()
for x in workingTickers:
    returnsDf[f"{x} returns"] = df[x].pct_change()
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
returnsDf
# Out:
#             TXG returns  FLWS returns  SRCE returns  TWOU returns  \
# Date
# 2019-09-12          NaN           NaN           NaN           NaN
# 2019-09-13    -0.009100      0.015313      0.004202     -0.059256
# 2019-09-16     0.056055     -0.015738      0.005230      0.023946
# 2019-09-17     0.028623     -0.016656     -0.008741     -0.003050
# 2019-09-18     0.091934     -0.023713     -0.003359     -0.087200
# ...                 ...           ...           ...           ...
# 2021-12-27    -0.011226      0.036080      0.010537     -0.037647
# 2021-12-28     0.000692     -0.010748     -0.002249     -0.016137
# 2021-12-29     0.001245      0.009996      0.004508     -0.005964
# 2021-12-30     0.042493      0.018503     -0.006732      0.025000
# 2021-12-31    -0.012725     -0.012674      0.018690     -0.020976
#
#             DDD returns  MMM returns  EGHT returns  AMRK returns  \
# Date
# 2019-09-12          NaN          NaN           NaN           NaN
# ...

# %%
df = pd.concat([df, returnsDf], axis=1)

# %%
df
# Out:
#                    TXG       FLWS       SRCE       TWOU        DDD  \
# Date
# 2019-09-12   52.750000  15.020000  42.914753  20.420000   8.490000
# 2019-09-13   52.270000  15.250000  43.095066  19.209999   8.490000
# 2019-09-16   55.200001  15.010000  43.320457  19.670000   8.670000
# 2019-09-17   56.779999  14.760000  42.941792  19.610001   8.650000
# 2019-09-18   62.000000  14.410000  42.797539  17.900000   8.420000
# ...                ...        ...        ...        ...        ...
# 2021-12-27  144.449997  23.260000  47.007420  20.450001  22.000000
# 2021-12-28  144.550003  23.010000  46.901699  20.120001  21.309999
# 2021-12-29  144.729996  23.240000  47.113140  20.000000  21.180000
# 2021-12-30  150.880005  23.670000  46.795979  20.500000  21.760000
# 2021-12-31  148.960007  23.370001  47.670574  20.070000  21.540001
#
#                    MMM       EGHT       AMRK       ATEN       AAON  ...  \
# Date                                                                ...
# ...

# %% [markdown]
# ## Cumulative Returns

# %%
cumulativeReturnsDF = pd.DataFrame()
for x in list(returnsDf.columns):
    cumulativeReturnsDF[f"{x} cumulative returns"] = (1 + returnsDf[f"{x}"]).cumprod()
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
cumulativeReturnsDF
# Out:
#             TXG returns cumulative returns  FLWS returns cumulative returns  \
# Date
# 2019-09-12                             NaN                              NaN
# 2019-09-13                        0.990900                         1.015313
# 2019-09-16                        1.046446                         0.999334
# 2019-09-17                        1.076398                         0.982690
# 2019-09-18                        1.175355                         0.959387
# ...                                    ...                              ...
# 2021-12-27                        2.738389                         1.548602
# 2021-12-28                        2.740284                         1.531957
# 2021-12-29                        2.743697                         1.547270
# 2021-12-30                        2.860284                         1.575899
# 2021-12-31                        2.823886                         1.555925
#
# ...

# %%
cumulativeReturnsDF
# Out:
#             TXG returns cumulative returns  FLWS returns cumulative returns  \
# Date
# 2019-09-12                             NaN                              NaN
# 2019-09-13                        0.990900                         1.015313
# 2019-09-16                        1.046446                         0.999334
# 2019-09-17                        1.076398                         0.982690
# 2019-09-18                        1.175355                         0.959387
# ...                                    ...                              ...
# 2021-12-27                        2.738389                         1.548602
# 2021-12-28                        2.740284                         1.531957
# 2021-12-29                        2.743697                         1.547270
# 2021-12-30                        2.860284                         1.575899
# 2021-12-31                        2.823886                         1.555925
#
# ...

# %%
df = pd.concat([df, cumulativeReturnsDF], axis=1)

# %%
df
# Out:
#                    TXG       FLWS       SRCE       TWOU        DDD  \
# Date
# 2019-09-12   52.750000  15.020000  42.914753  20.420000   8.490000
# 2019-09-13   52.270000  15.250000  43.095066  19.209999   8.490000
# 2019-09-16   55.200001  15.010000  43.320457  19.670000   8.670000
# 2019-09-17   56.779999  14.760000  42.941792  19.610001   8.650000
# 2019-09-18   62.000000  14.410000  42.797539  17.900000   8.420000
# ...                ...        ...        ...        ...        ...
# 2021-12-27  144.449997  23.260000  47.007420  20.450001  22.000000
# 2021-12-28  144.550003  23.010000  46.901699  20.120001  21.309999
# 2021-12-29  144.729996  23.240000  47.113140  20.000000  21.180000
# 2021-12-30  150.880005  23.670000  46.795979  20.500000  21.760000
# 2021-12-31  148.960007  23.370001  47.670574  20.070000  21.540001
#
#                    MMM       EGHT       AMRK       ATEN       AAON  ...  \
# Date                                                                ...
# ...

# %% [markdown]
# ### Normalized returns

# %%
normalDF = pd.DataFrame()
for x in workingTickers:
    normalDF[f"{x} normmalized return"] = df[x]/df.iloc[0][x]
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
normalDF
# Out:
#             TXG normmalized return  FLWS normmalized return  \
# Date
# 2019-09-12                1.000000                 1.000000
# 2019-09-13                0.990900                 1.015313
# 2019-09-16                1.046446                 0.999334
# 2019-09-17                1.076398                 0.982690
# 2019-09-18                1.175355                 0.959387
# ...                            ...                      ...
# 2021-12-27                2.738389                 1.548602
# 2021-12-28                2.740284                 1.531957
# 2021-12-29                2.743697                 1.547270
# 2021-12-30                2.860284                 1.575899
# 2021-12-31                2.823886                 1.555925
#
#             SRCE normmalized return  TWOU normmalized return  \
# Date
# 2019-09-12                 1.000000                 1.000000
# 2019-09-13                 1.004202                 0.940744
# ...

# %%
cumulativeReturnsDF
# Out:
#             TXG returns cumulative returns  FLWS returns cumulative returns  \
# Date
# 2019-09-12                             NaN                              NaN
# 2019-09-13                        0.990900                         1.015313
# 2019-09-16                        1.046446                         0.999334
# 2019-09-17                        1.076398                         0.982690
# 2019-09-18                        1.175355                         0.959387
# ...                                    ...                              ...
# 2021-12-27                        2.738389                         1.548602
# 2021-12-28                        2.740284                         1.531957
# 2021-12-29                        2.743697                         1.547270
# 2021-12-30                        2.860284                         1.575899
# 2021-12-31                        2.823886                         1.555925
#
# ...

# %% [markdown]
# ### Allocation
# - we will aim to be random at the moment

# %%
allocations = np.array(np.random.random(len(workingTickers)))

# %%
allocations
# Out:
# array([0.00806915, 0.90576707, 0.49104541, ..., 0.13527115, 0.47748126,
#        0.59267347])

# %%
allocationDf = pd.DataFrame()
for ticker, allocation in zip(workingTickers, allocations):
    allocationDf[f"{ticker} allocation"] = normalDF[f"{x} normmalized return"] * allocation
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
allocationDf
# Out:
#             TXG allocation  FLWS allocation  SRCE allocation  TWOU allocation  \
# Date
# 2019-09-12        0.008069         0.905767         0.491045         0.386603
# 2019-09-13        0.008484         0.952325         0.516286         0.406475
# 2019-09-16        0.008427         0.945976         0.512844         0.403765
# 2019-09-17        0.008861         0.994651         0.539232         0.424541
# 2019-09-18        0.008823         0.990418         0.536938         0.422734
# ...                    ...              ...              ...              ...
# 2021-12-27        0.009879         1.108930         0.601186         0.473318
# 2021-12-28        0.009474         1.063430         0.576520         0.453897
# 2021-12-29        0.009398         1.054965         0.571930         0.450284
# 2021-12-30        0.009643         1.082476         0.586845         0.462027
# 2021-12-31        0.009398         1.054965         0.571930         0.450284
#
# ...

# %%
allocationDf.iloc[-1].sort_values()
# Out:
# FISI allocation     0.000744
# CTBI allocation     0.001707
# APLT allocation     0.001966
# FCNCA allocation    0.002477
# CBT allocation      0.003477
#                       ...
# TRTN allocation     1.157252
# UEC allocation      1.158548
# AR allocation       1.159196
# PKI allocation      1.159262
# AEIS allocation     1.163242
# Name: 2021-12-31 00:00:00, Length: 1553, dtype: float64

# %%
df = pd.concat([df, allocationDf], axis = 1)

# %%
df
# Out:
#                    TXG       FLWS       SRCE       TWOU        DDD  \
# Date
# 2019-09-12   52.750000  15.020000  42.914753  20.420000   8.490000
# 2019-09-13   52.270000  15.250000  43.095066  19.209999   8.490000
# 2019-09-16   55.200001  15.010000  43.320457  19.670000   8.670000
# 2019-09-17   56.779999  14.760000  42.941792  19.610001   8.650000
# 2019-09-18   62.000000  14.410000  42.797539  17.900000   8.420000
# ...                ...        ...        ...        ...        ...
# 2021-12-27  144.449997  23.260000  47.007420  20.450001  22.000000
# 2021-12-28  144.550003  23.010000  46.901699  20.120001  21.309999
# 2021-12-29  144.729996  23.240000  47.113140  20.000000  21.180000
# 2021-12-30  150.880005  23.670000  46.795979  20.500000  21.760000
# 2021-12-31  148.960007  23.370001  47.670574  20.070000  21.540001
#
#                    MMM       EGHT       AMRK       ATEN       AAON  ...  \
# Date                                                                ...
# ...

# %%
df["portfolio Return"] = returnsDf.sum(axis=1)
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                    TXG       FLWS       SRCE       TWOU        DDD  \
# Date
# 2019-09-12   52.750000  15.020000  42.914753  20.420000   8.490000
# 2019-09-13   52.270000  15.250000  43.095066  19.209999   8.490000
# 2019-09-16   55.200001  15.010000  43.320457  19.670000   8.670000
# 2019-09-17   56.779999  14.760000  42.941792  19.610001   8.650000
# 2019-09-18   62.000000  14.410000  42.797539  17.900000   8.420000
# ...                ...        ...        ...        ...        ...
# 2021-12-27  144.449997  23.260000  47.007420  20.450001  22.000000
# 2021-12-28  144.550003  23.010000  46.901699  20.120001  21.309999
# 2021-12-29  144.729996  23.240000  47.113140  20.000000  21.180000
# 2021-12-30  150.880005  23.670000  46.795979  20.500000  21.760000
# 2021-12-31  148.960007  23.370001  47.670574  20.070000  21.540001
#
#                    MMM       EGHT       AMRK       ATEN       AAON  ...  \
# Date                                                                ...
# ...

# %%
df["portfolio Return"].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def classifyReturn(portReturn):
    if portReturn < 1:
        return 0
    else:
        return 1

# %%
df["target"] = df["portfolio Return"].apply(classifyReturn)
# Out:
# /Users/berkatbhatti/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                    TXG       FLWS       SRCE       TWOU        DDD  \
# Date
# 2019-09-12   52.750000  15.020000  42.914753  20.420000   8.490000
# 2019-09-13   52.270000  15.250000  43.095066  19.209999   8.490000
# 2019-09-16   55.200001  15.010000  43.320457  19.670000   8.670000
# 2019-09-17   56.779999  14.760000  42.941792  19.610001   8.650000
# 2019-09-18   62.000000  14.410000  42.797539  17.900000   8.420000
# ...                ...        ...        ...        ...        ...
# 2021-12-27  144.449997  23.260000  47.007420  20.450001  22.000000
# 2021-12-28  144.550003  23.010000  46.901699  20.120001  21.309999
# 2021-12-29  144.729996  23.240000  47.113140  20.000000  21.180000
# 2021-12-30  150.880005  23.670000  46.795979  20.500000  21.760000
# 2021-12-31  148.960007  23.370001  47.670574  20.070000  21.540001
#
#                    MMM       EGHT       AMRK       ATEN       AAON  ...  \
# Date                                                                ...
# ...

# %%
dd = df.dropna(axis=1)

# %%
X = dd.drop("target", axis = 1).values
y = dd["target"].values

# %%
sns.countplot(x = df["target"])
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, explained_variance_score
from sklearn.preprocessing import MinMaxScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (407, 3107)

# %%
scalar = MinMaxScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()

model.add(Dense(units=4000, activation="relu"))
model.add(Dense(units=4000, activation="relu"))
model.add(Dense(units=4000, activation="relu"))
model.add(Dense(units=4000, activation="relu"))

model.add(Dense(units=3000, activation="relu"))
model.add(Dense(units=3000, activation="relu"))

model.add(Dense(units=2000, activation="relu"))
model.add(Dense(units=2000, activation="relu"))


model.add(Dense(units=1, activation="sigmoid"))
model.compile(loss = "binary_crossentropy", optimimizer = "adam", metrics = ["accuracy"])

# %%
stop = EarlyStopping(patience=50)

# %%
model.fit(X_train, y_train, epochs = 250, validation_data = (X_test, y_test), callbacks = [stop])
# Out:
# Train on 407 samples, validate on 175 samples
# Epoch 1/250
# 407/407 [==============================] - 7s 17ms/sample - loss: 4607.8851 - accuracy: 0.4963 - val_loss: 0.7289 - val_accuracy: 0.4457
# Epoch 2/250
# 407/407 [==============================] - 6s 14ms/sample - loss: 0.7411 - accuracy: 0.5258 - val_loss: 0.6937 - val_accuracy: 0.4457
# Epoch 3/250
# 407/407 [==============================] - 6s 14ms/sample - loss: 0.6957 - accuracy: 0.5012 - val_loss: 0.6924 - val_accuracy: 0.5486
# Epoch 4/250
# 407/407 [==============================] - 6s 14ms/sample - loss: 0.6955 - accuracy: 0.4988 - val_loss: 0.6941 - val_accuracy: 0.4457
# Epoch 5/250
# 407/407 [==============================] - 6s 15ms/sample - loss: 0.6933 - accuracy: 0.5037 - val_loss: 0.6923 - val_accuracy: 0.5314
# Epoch 6/250
# 407/407 [==============================] - 6s 14ms/sample - loss: 0.7320 - accuracy: 0.4988 - val_loss: 0.7008 - val_accuracy: 0.4457
# Epoch 7/250
# ...

# %%
pd.DataFrame(model.history.history)
# Out:
#            loss  accuracy  val_loss  val_accuracy
# 0   4607.885119  0.496314  0.728950      0.445714
# 1      0.741057  0.525798  0.693686      0.445714
# 2      0.695676  0.501229  0.692354      0.548571
# 3      0.695456  0.498771  0.694066      0.445714
# 4      0.693258  0.503685  0.692268      0.531429
# 5      0.731998  0.498771  0.700809      0.445714
# 6      1.241070  0.540541  0.694131      0.445714
# 7      0.701038  0.525798  0.743042      0.554286
# 8      0.706700  0.457002  0.693727      0.445714
# 9      0.693660  0.496314  0.694661      0.445714
# 10     0.693145  0.525798  0.694956      0.445714
# 11     0.697015  0.515971  0.694398      0.445714
# 12     0.694763  0.506142  0.694888      0.445714
# 13     0.868300  0.508600  0.698430      0.445714
# 14     0.694825  0.498771  0.695978      0.445714
# 15     0.835494  0.530713  0.694020      0.445714
# 16     0.693385  0.493858  0.692397      0.531429
# 17     0.693601  0.513514  0.693834      0.445714
# ...
