# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SearchResults.csv")

# %%
df.drop("Rank", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NCT Number               10000 non-null  object
#  1   Title                    10000 non-null  object
#  2   Acronym                  2619 non-null   object
#  3   Status                   10000 non-null  object
#  4   Study Results            10000 non-null  object
#  5   Conditions               10000 non-null  object
#  6   Interventions            9597 non-null   object
#  7   Outcome Measures         9540 non-null   object
#  8   Sponsor/Collaborators    10000 non-null  object
#  9   Gender                   9993 non-null   object
#  10  Age                      10000 non-null  object
#  11  Phases                   8838 non-null   object
#  12  Enrollment               9778 non-null   float64
#  13  Funded Bys               10000 non-null  object
#  14  Study Type               10000 non-null  object
#  15  Study Designs            9912 non-null   object
#  16  Other IDs                10000 non-null  object
#  17  Start Date               9819 non-null   object
#  18  Primary Completion Date  9502 non-null   object
#  19  Completion Date          9514 non-null   object
#  20  First Posted             10000 non-null  object
#  21  Results First Posted     3357 non-null   object
#  22  Last Update Posted       10000 non-null  object
#  23  Locations                10000 non-null  object
#  24  Study Documents          1729 non-null   object
#  25  URL                      10000 non-null  object
# dtypes: float64(1), object(25)
# memory usage: 2.0+ MB

# %% [markdown]
# # Missing Data
# - Handling Missing Data

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.drop("Acronym", axis=1, inplace=True)

# %% [markdown]
# ## Intervertentions
# - we can use other data features to replace the missing values
# - gender has Male, Female, All

# %%
gender = pd.get_dummies(df["Gender"], drop_first=True)

# %%
df = pd.concat([df, gender], axis=1)

# %%
sns.countplot(x = df["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df.drop("Gender", axis=1, inplace=True)

# %% [markdown]
# ## Study Doc
# - Dropping missing too many values

# %%
df.drop("Study Documents", axis=1, inplace=True)

# %%
df.drop("Results First Posted", axis=1, inplace=True)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["organization"] = df["Locations"].apply(lambda x : x.split(",")[0])

# %%
df["state"] = df["Locations"].apply(lambda x : x.split(",")[-2])

# %%
df.drop("Locations", axis=1, inplace=True)

# %% [markdown]
# ## Drpping NA for the time being

# %%
df = df.dropna(axis=0)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["Status"].unique()
# Out:
# array(['Recruiting', 'Not yet recruiting', 'Enrolling by invitation',
#        'Completed', 'Active, not recruiting', 'Terminated', 'Withdrawn',
#        'Suspended', 'Unknown status'], dtype=object)

# %%
lisyFOrStatue = list(enumerate(df["Status"].unique()))

# %%
statusINdex = [x[0] for x in lisyFOrStatue]

# %%
status = [x[1] for x in lisyFOrStatue]

# %%
statusDict = dict(list(zip(status, statusINdex)))

# %%
df["Status"] = df["Status"].apply(lambda x: statusDict[x])

# %%
df["Study Results"].nunique()
# Out:
# 2

# %%
df["Study Results"] = pd.get_dummies(df["Study Results"], drop_first=True)

# %% [markdown]
# ## AGe

# %%
df["Age"] = df["Age"].apply(lambda x : x.split(",")[0].split("(")[0])

# %%
df["Age"].nunique()
# Out:
# 543

# %%
df["Age"] = df["Age"].apply(lambda x : x.split("/")[0])

# %%
df["Age"].nunique()
# Out:
# 543

# %%
listOFAges = list(enumerate(df["Age"].unique()))

# %%
ageIndex = [x[0] for x in listOFAges]

# %%
age = [x[1] for x in listOFAges]

# %%
zippyAge = dict(zip(age, ageIndex))

# %%
df["Age"] = df["Age"].apply(lambda x : zippyAge[x])

# %%
phases = pd.get_dummies(df["Phases"], drop_first=True)

# %%
df = pd.concat([df, phases], axis=1)

# %%
df.drop("Phases", axis=1, inplace=True)

# %%
df["Sponsor/Collaborators"].nunique()
# Out:
# 2843

# %%
spoandcolab = list(enumerate(df["Sponsor/Collaborators"].unique()))

# %%
spoINdex = [x[0] for x in spoandcolab]

# %%
spo = [x[1] for x in spoandcolab]

# %%
spoDict = dict(zip(spo, spoINdex))

# %%
df["Sponsor/Collaborators"] = df["Sponsor/Collaborators"].apply(lambda x : spoDict[x])

# %%
df.columns
# Out:
# Index(['NCT Number', 'Title', 'Status', 'Study Results', 'Conditions',
#        'Interventions', 'Outcome Measures', 'Sponsor/Collaborators', 'Age',
#        'Enrollment', 'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs',
#        'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Last Update Posted', 'URL', 'Female', 'Male',
#        'organization', 'state', 'Not Applicable', 'Phase 1', 'Phase 1|Phase 2',
#        'Phase 2', 'Phase 2|Phase 3', 'Phase 3', 'Phase 4'],
#       dtype='object')

# %%
df.drop("Outcome Measures", axis = 1,  inplace=True)

# %%
df["Conditions"] = df["Conditions"].apply(lambda x : x.split("|")[0])

# %%
condList = list(enumerate(df["Conditions"].unique()))

# %%
condIndex = [x[0] for x in condList]

# %%
cond = [x[1] for x in condList]

# %%
conDict = dict(zip(cond, condIndex))

# %%
df["Conditions"] = df["Conditions"].apply(lambda x: conDict[x])

# %%
df["Interventions"] = df["Interventions"].apply(lambda x:x.split(":")[0])

# %%
df["Interventions"].nunique()
# Out:
# 11

# %%
interventionList = list(enumerate(df["Interventions"].unique()))

# %%
interIndex = [x[0] for x in interventionList]

# %%
interv = [x[1] for x in interventionList]

# %%
interDict = dict(zip(interv, interIndex))

# %%
df["Interventions"] = df["Interventions"].apply(lambda x : interDict[x])

# %%
df.drop(["Title","NCT Number"], axis=1, inplace=True)

# %%
df["Funded Bys"].nunique()
# Out:
# 29

# %%
fundedLit = list(enumerate(df["Funded Bys"].unique()))

# %%
fundedUndex = [x[0] for x in fundedLit]

# %%
funded = [x[1] for x in fundedLit]

# %%
fundedDict = dict(zip(funded, fundedUndex))

# %%
df["Funded Bys"] = df["Funded Bys"].apply(lambda x: fundedDict[x])

# %% [markdown]
# ## Drop only one type

# %%
df["Study Type"]
# Out:
# 1       Interventional
# 2       Interventional
# 3       Interventional
# 5       Interventional
# 7       Interventional
#              ...
# 9995    Interventional
# 9996    Interventional
# 9997    Interventional
# 9998    Interventional
# 9999    Interventional
# Name: Study Type, Length: 8065, dtype: object

# %%
df["Study Type"].nunique()
# Out:
# 1

# %%
df.drop("Study Type", axis=1, inplace=True)

# %%
df["Allocation"] = df["Study Designs"].apply(lambda x : x.split("|")[0].split(":")[1])

# %%
df["Allocation"].nunique()
# Out:
# 11

# %%
alloList = list(enumerate(df["Allocation"].unique()))

# %%
alloIndex = [x[0] for x in alloList]

# %%
allo = [x[1] for x in alloList]

# %%
alloDict = dict(zip(allo, alloIndex))

# %%
df["Allocation"] = df["Allocation"].apply(lambda x: alloDict[x])

# %%
df.drop("Study Designs", axis=1, inplace=True)

# %%
df.drop("Other IDs", axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['Status', 'Study Results', 'Conditions', 'Interventions',
#        'Sponsor/Collaborators', 'Age', 'Enrollment', 'Funded Bys',
#        'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Last Update Posted', 'URL', 'Female', 'Male',
#        'organization', 'state', 'Not Applicable', 'Phase 1', 'Phase 1|Phase 2',
#        'Phase 2', 'Phase 2|Phase 3', 'Phase 3', 'Phase 4', 'Allocation'],
#       dtype='object')

# %% [markdown]
# ## Dropping URL

# %%
df.drop("URL", axis=1, inplace=True)

# %% [markdown]
# ## Dates

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df["Start day"] = [x.day for x in df["Start Date"]]

# %%
df["Start month"] = [x.month for x in df["Start Date"]]

# %%
df["Start year"] = [x.year for x in df["Start Date"]]

# %%
df.drop("Start Date", axis=1, inplace=True)

# %%
df["Primary Completion Date"] = pd.to_datetime(df["Primary Completion Date"])

# %%
df["Primary Completion Day"] = [x.day for x in df["Primary Completion Date"]]

# %%
df["Primary Completion month"] = [x.month for x in df["Primary Completion Date"]]

# %%
df["Primary Completion year"] = [x.year for x in df["Primary Completion Date"]]

# %%
df.drop("Primary Completion Date", axis=1, inplace=True)

# %%
df["Completion Date"] = pd.to_datetime(df["Completion Date"])

# %%
df["Completion Day"] = [x.day for x in df["Completion Date"]]

# %%
df["Completion Month"] = [x.month for x in df["Completion Date"]]

# %%
df["Completion year"] = [x.year for x in df["Completion Date"]]

# %%
df.drop("Completion Date", axis=1, inplace=True)

# %%
df["First Posted"] = pd.to_datetime(df["First Posted"])

# %%
df["First Posted Day"] = [x.day for x in df["First Posted"]]

# %%
df["First Posted Month"] = [x.month for x in df["First Posted"]]

# %%
df["First Posted year"] = [x.year for x in df["First Posted"]]

# %%
df.drop("First Posted", axis=1, inplace=True)

# %%
df["Last Update Posted"] = pd.to_datetime(df["Last Update Posted"])

# %%
df["Last Update Posted Day"] = [x.day for x in df["Last Update Posted"]]

# %%
df["Last Update Posted Month"] = [x.month for x in df["Last Update Posted"]]

# %%
df["Last Update Posted Year"] = [x.year for x in df["Last Update Posted"]]

# %%
df.drop("Last Update Posted", axis=1, inplace=True)

# %% [markdown]
# ## Org and state

# %%
df["organization"].nunique()
# Out:
# 3187

# %%
orgList = list(enumerate(df["organization"].unique()))

# %%
orgIndex = [x[0] for x in orgList]

# %%
org = [x[1] for x in orgList]

# %%
orgDict = dict(zip(org, orgIndex))

# %%
df["organization"] = df["organization"].apply(lambda x : orgDict[x])

# %%
statList = list(enumerate(df["state"].unique()))

# %%
stateIndex = [x[0] for x in statList]

# %%
state = [x[1] for x in statList]

# %%
stateDict = dict(zip(state, spoINdex))

# %%
df["state"] = df["state"].apply(lambda x: stateDict[x])

# %%
df.corrwith(df["Status"]).sort_values().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.corr(), annot=True,cbar=False, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Creation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.metrics import confusion_matrix, classification_report, explained_variance_score

# %%
X = df.drop("Status", axis=1).values
y = df["Status"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense

# %%
scalar = MinMaxScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
X_train.shape
# Out:
# (5645, 34)

# %%
model = Sequential()
model.add(Dense(units=120, activation="relu"))
model.add(Dense(units=120, activation="relu"))

model.add(Dense(units=1, activation="sigmoid"))

model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
stop = EarlyStopping(patience=150)

# %%
model.fit(X_train, y_train, epochs = 600, validation_data = (X_test, y_test), callbacks = [stop] )
# Out:
# Train on 5645 samples, validate on 2420 samples
# Epoch 1/600
# 5645/5645 [==============================] - 2s 322us/sample - loss: -898.1424 - accuracy: 0.0080 - val_loss: -4150.2905 - val_accuracy: 0.0058
# Epoch 2/600
# 5645/5645 [==============================] - 1s 181us/sample - loss: -18757.2790 - accuracy: 0.0076 - val_loss: -42623.1877 - val_accuracy: 0.0058
# Epoch 3/600
# 5645/5645 [==============================] - 1s 172us/sample - loss: -90556.7067 - accuracy: 0.0076 - val_loss: -152761.0098 - val_accuracy: 0.0058
# Epoch 4/600
# 5645/5645 [==============================] - 1s 172us/sample - loss: -251158.6420 - accuracy: 0.0076 - val_loss: -366480.6544 - val_accuracy: 0.0058
# Epoch 5/600
# 5645/5645 [==============================] - 1s 171us/sample - loss: -527951.4459 - accuracy: 0.0076 - val_loss: -707391.9622 - val_accuracy: 0.0058
# Epoch 6/600
# 5645/5645 [==============================] - 1s 174us/sample - loss: -942614.8892 - accuracy: 0.0076 - val_loss: -1193594.2147 - val_accuracy: 0.0058
# Epoch 7/600
# 5645/5645 [==============================] - 1s 201us/sample - loss: -1513618.6923 - accuracy: 0.0076 - val_loss: -1845240.9983 - val_accuracy: 0.0058
# Epoch 8/600
# 5645/5645 [==============================] - 1s 188us/sample - loss: -2259322.0555 - accuracy: 0.0076 - val_loss: -2670787.2083 - val_accuracy: 0.0058
# Epoch 9/600
# 5645/5645 [==============================] - 1s 184us/sample - loss: -3195394.9682 - accuracy: 0.0076 - val_loss: -3697053.5298 - val_accuracy: 0.0058
# Epoch 10/600
# 5645/5645 [==============================] - 1s 186us/sample - loss: -4328643.8760 - accuracy: 0.0076 - val_loss: -4918276.2992 - val_accuracy: 0.0058
# Epoch 11/600
# 5645/5645 [==============================] - 1s 210us/sample - loss: -5663918.5859 - accuracy: 0.0076 - val_loss: -6359172.6826 - val_accuracy: 0.0058
# Epoch 12/600
# 5645/5645 [==============================] - 1s 178us/sample - loss: -7212729.4970 - accuracy: 0.0076 - val_loss: -7996729.7025 - val_accuracy: 0.0058
# Epoch 13/600
# 5645/5645 [==============================] - 1s 186us/sample - loss: -8982606.5456 - accuracy: 0.0076 - val_loss: -9870813.3256 - val_accuracy: 0.0058
# Epoch 14/600
# 5645/5645 [==============================] - 1s 258us/sample - loss: -10983393.7318 - accuracy: 0.0076 - val_loss: -11959821.0942 - val_accuracy: 0.0058
# Epoch 15/600
# 5645/5645 [==============================] - 1s 215us/sample - loss: -13219851.7906 - accuracy: 0.0076 - val_loss: -14303490.4760 - val_accuracy: 0.0058
# Epoch 16/600
# 5645/5645 [==============================] - 1s 180us/sample - loss: -15695599.8818 - accuracy: 0.0076 - val_loss: -16878609.4512 - val_accuracy: 0.0058
# Epoch 17/600
# 5645/5645 [==============================] - 1s 181us/sample - loss: -18419072.8324 - accuracy: 0.0076 - val_loss: -19700116.5289 - val_accuracy: 0.0058
# Epoch 18/600
# 5645/5645 [==============================] - 1s 172us/sample - loss: -21397114.8450 - accuracy: 0.0076 - val_loss: -22780719.9736 - val_accuracy: 0.0058
# Epoch 19/600
# 5645/5645 [==============================] - 1s 175us/sample - loss: -24634740.0719 - accuracy: 0.0076 - val_loss: -26110760.7207 - val_accuracy: 0.0058
# Epoch 20/600
# 5645/5645 [==============================] - 1s 174us/sample - loss: -28127365.6794 - accuracy: 0.0076 - val_loss: -29717580.0000 - val_accuracy: 0.0058
# Epoch 21/600
# 5645/5645 [==============================] - 1s 176us/sample - loss: -31881176.3454 - accuracy: 0.0076 - val_loss: -33571236.9058 - val_accuracy: 0.0058
# Epoch 22/600
# 5645/5645 [==============================] - 1s 201us/sample - loss: -35903006.4220 - accuracy: 0.0076 - val_loss: -37682863.7752 - val_accuracy: 0.0058
# Epoch 23/600
# 5645/5645 [==============================] - 1s 182us/sample - loss: -40202606.0266 - accuracy: 0.0076 - val_loss: -42088591.4182 - val_accuracy: 0.0058
# Epoch 24/600
# 5645/5645 [==============================] - 1s 174us/sample - loss: -44787239.4051 - accuracy: 0.0076 - val_loss: -46789887.9603 - val_accuracy: 0.0058
# Epoch 25/600
# 5645/5645 [==============================] - 1s 182us/sample - loss: -49642627.4771 - accuracy: 0.0076 - val_loss: -51737872.5355 - val_accuracy: 0.0058
# Epoch 26/600
# 5645/5645 [==============================] - 1s 192us/sample - loss: -54791474.5297 - accuracy: 0.0076 - val_loss: -56987622.3339 - val_accuracy: 0.0058
# Epoch 27/600
# 5645/5645 [==============================] - 1s 184us/sample - loss: -60241043.4353 - accuracy: 0.0076 - val_loss: -62536440.6612 - val_accuracy: 0.0058
# Epoch 28/600
# 5645/5645 [==============================] - 1s 180us/sample - loss: -65994161.0997 - accuracy: 0.0076 - val_loss: -68359027.1736 - val_accuracy: 0.0058
# Epoch 29/600
# 5645/5645 [==============================] - 1s 206us/sample - loss: -72042801.6425 - accuracy: 0.0076 - val_loss: -74527376.0529 - val_accuracy: 0.0058
# Epoch 30/600
# 5645/5645 [==============================] - 1s 204us/sample - loss: -78405659.5252 - accuracy: 0.0076 - val_loss: -81000175.7620 - val_accuracy: 0.0058
# Epoch 31/600
# 5645/5645 [==============================] - 1s 173us/sample - loss: -85075116.0347 - accuracy: 0.0076 - val_loss: -87746882.5256 - val_accuracy: 0.0058
# Epoch 32/600
# 5645/5645 [==============================] - 1s 203us/sample - loss: -92061988.6923 - accuracy: 0.0076 - val_loss: -94837858.1950 - val_accuracy: 0.0058
# Epoch 33/600
# 5645/5645 [==============================] - 1s 185us/sample - loss: -99365720.8376 - accuracy: 0.0076 - val_loss: -102242818.1554 - val_accuracy: 0.0058
# Epoch 34/600
# 5645/5645 [==============================] - 1s 184us/sample - loss: -106997749.6291 - accuracy: 0.0076 - val_loss: -109974009.5603 - val_accuracy: 0.0058
# Epoch 35/600
# 5645/5645 [==============================] - 1s 181us/sample - loss: -114957259.5812 - accuracy: 0.0076 - val_loss: -118028020.2050 - val_accuracy: 0.0058
# Epoch 36/600
# 5645/5645 [==============================] - 1s 187us/sample - loss: -123257377.7488 - accuracy: 0.0076 - val_loss: -126422184.6744 - val_accuracy: 0.0058
# Epoch 37/600
# 5645/5645 [==============================] - 1s 200us/sample - loss: -131903822.8776 - accuracy: 0.0076 - val_loss: -135163390.3603 - val_accuracy: 0.0058
# Epoch 38/600
# 5645/5645 [==============================] - 1s 195us/sample - loss: -140907864.5541 - accuracy: 0.0076 - val_loss: -144233506.6975 - val_accuracy: 0.0058
# Epoch 39/600
# 5645/5645 [==============================] - 1s 199us/sample - loss: -150267089.1012 - accuracy: 0.0076 - val_loss: -153722701.2760 - val_accuracy: 0.0058
# Epoch 40/600
# 5645/5645 [==============================] - 1s 190us/sample - loss: -159973318.8195 - accuracy: 0.0076 - val_loss: -163518306.1421 - val_accuracy: 0.0058
# Epoch 41/600
# 5645/5645 [==============================] - 1s 211us/sample - loss: -170047332.1467 - accuracy: 0.0076 - val_loss: -173697573.7124 - val_accuracy: 0.0058
# Epoch 42/600
# 5645/5645 [==============================] - 1s 216us/sample - loss: -180474323.1178 - accuracy: 0.0076 - val_loss: -184200002.0099 - val_accuracy: 0.0058
# Epoch 43/600
# 5645/5645 [==============================] - 1s 190us/sample - loss: -191287257.9345 - accuracy: 0.0076 - val_loss: -195115613.7785 - val_accuracy: 0.0058
# Epoch 44/600
# 5645/5645 [==============================] - 1s 263us/sample - loss: -202468610.7635 - accuracy: 0.0076 - val_loss: -206377133.4876 - val_accuracy: 0.0058
# Epoch 45/600
# 5645/5645 [==============================] - 1s 189us/sample - loss: -214026741.4845 - accuracy: 0.0076 - val_loss: -217999155.2000 - val_accuracy: 0.0058
# Epoch 46/600
# 5645/5645 [==============================] - 1s 191us/sample - loss: -225980691.2921 - accuracy: 0.0076 - val_loss: -230051079.9074 - val_accuracy: 0.0058
# Epoch 47/600
# 5645/5645 [==============================] - 1s 187us/sample - loss: -238307963.5642 - accuracy: 0.0076 - val_loss: -242459696.6612 - val_accuracy: 0.0058
# Epoch 48/600
# 5645/5645 [==============================] - 1s 193us/sample - loss: -251053391.5748 - accuracy: 0.0076 - val_loss: -255298468.0727 - val_accuracy: 0.0058
# Epoch 49/600
# 5645/5645 [==============================] - 1s 178us/sample - loss: -264195873.3010 - accuracy: 0.0076 - val_loss: -268523725.5405 - val_accuracy: 0.0058
# Epoch 50/600
# 5645/5645 [==============================] - 1s 186us/sample - loss: -277725347.6110 - accuracy: 0.0076 - val_loss: -282169898.4727 - val_accuracy: 0.0058
# Epoch 51/600
#   32/5645 [..............................] - ETA: 1s - loss: -273229632.0000 - accuracy: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/44/4288ncqn6p3cxnm99z8rvcl80000gp/T/ipykernel_9164/4175246917.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs = 600, validation_data = (X_test, y_test), callbacks = [stop] )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# Out:
#       Status  Study Results  Conditions  Interventions  Sponsor/Collaborators  \
# 1          0              1           0              0                      0
# 2          1              1           1              1                      1
# 3          0              1           2              1                      2
# 5          1              1           3              2                      2
# 7          1              1           4              3                      3
# ...      ...            ...         ...            ...                    ...
# 9995       4              1        2882              8                    399
# 9996       3              0        2733              0                   2841
# 9997       3              0          35              3                    358
# 9998       3              1        2883              5                   2842
# 9999       3              0        1256              5                    358
#
#       Age  Enrollment  Funded Bys  Female  Male  ...  Primary Completion year  \
# 1       0        36.0           0       0     0  ...                     2024
# 2       1       420.0           1       0     0  ...                     2026
# 3       2        32.0           0       0     0  ...                     2024
# 5       3        12.0           0       0     0  ...                     2024
# 7       0        40.0           2       0     0  ...                     2023
# ...   ...         ...         ...     ...   ...  ...                      ...
# 9995    6       300.0          14       0     0  ...                     2023
# 9996   22      1028.0           2       0     0  ...                     2018
# 9997  171        50.0           2       0     0  ...                     2016
# 9998    3        50.0           2       0     0  ...                     2014
# 9999    6       650.0           2       0     0  ...                     2016
#
#       Completion Day  Completion Month  Completion year  First Posted Day  \
# 1                  1                 9             2024                13
# 2                 30                 8             2026                 8
# 3                 31                 7             2024                 6
# 5                  1                 8             2024                16
# 7                  1                 4             2023                15
# ...              ...               ...              ...               ...
# 9995               2                10             2023                25
# 9996              26                 3             2019                25
# 9997               1                 3             2016                25
# 9998               1                 2             2015                22
# 9999               1                 6             2017                21
#
#       First Posted Month  First Posted year  Last Update Posted Day  \
# 1                      3               2023                      13
# 2                      3               2023                       8
# 3                      3               2023                       6
# 5                      2               2023                      16
# 7                      2               2023                      15
# ...                  ...                ...                     ...
# 9995                   8               2014                      10
# 9996                   8               2014                      27
# 9997                   8               2014                      27
# 9998                   8               2014                      14
# 9999                   8               2014                      30
#
#       Last Update Posted Month  Last Update Posted Year
# 1                            3                     2023
# 2                            3                     2023
# 3                            3                     2023
# 5                            2                     2023
# 7                            2                     2023
# ...                        ...                      ...
# 9995                         3                     2023
# 9996                         6                     2022
# 9997                         3                     2017
# 9998                         4                     2016
# 9999                         5                     2018
#
# [8065 rows x 35 columns]

# %%
df["URL"].iloc[1]
# Out:
# 'https://ClinicalTrials.gov/show/NCT05760573'

# %%
#### import json
import requests

from bs4 import BeautifulSoup

URL = ("https://clinicaltrials.gov/ct2/show/record/NCT05768113?map_cntry=US&map_state=US%3ANJ&draw=2&rank=1")
oururl= requests.get(URL, "r")

# %%
oururl.text
# Out:
# '\r\n\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml" lang=\'en\'>\n<head>  \n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    <meta name="robots" content="noindex,nofollow"/>\n    <meta name="referrer" content="origin-when-cross-origin"/>\n  <title>LAEH Formulation Nasal Spray to Reduce Viral Load - Tabular View - ClinicalTrials.gov</title>\n    <link href="/ct2/show/record/NCT05768113" rel="canonical"/>\n    \n  <!-- Twitter Card data -->\n  <meta name="twitter:card" content="summary">\n  <meta name="twitter:image" content="https://clinicaltrials.gov/ct2/html/images/ct.gov-nlm-nih-square-logo.png?v1">\n\n  <!-- Open Graph data -->\n  <meta property="og:type" content="article" />\n  <meta property="og:title" content="LAEH Formulation Nasal Spray to Reduce Viral Load - Tabular View - ClinicalTrials.gov">\n  <meta property="og:image" content="https://clinicaltrials.gov/ct2/html/images/ct.gov-nlm-nih-square-logo.png?v1">\n    <meta property="og:description" content="LAEH Formulation Nasal Spray to Reduce Viral Load - Tabular View.">\n  <meta property="og:url" content="https://clinicaltrials.gov/ct2/show/record/NCT05768113">\n    \n  <link rel="shortcut icon" href="/ct2/html/images/favicon.ico" />\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-144x144.png\' sizes=\'144x144\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-114x114.png\' sizes=\'114x114\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-72x72.png\'   sizes=\'72x72\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-precomposed.png\' >\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon.png\' >\n\n  <link rel="stylesheet" type="text/css" href="/ct2/html/jquery/css/superfish.css?v=48" media="screen" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/jquery/css/superfish-vertical.css?v=48" media="screen" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/glossary.css?v=48" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/base.css?v=48" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/print.css?v=48" media="print" />\n  <link rel="stylesheet" href="/ct2/html/css/w3-ct.css?v=48" type="text/css" />\n  <!--[if lt IE 9]>\n\t<link rel="stylesheet" href="/ct2/html/css/w3-ct-oldIE.css?v=48" type="text/css" />\n  <![endif]-->\n   \t\n  <link rel="preconnect" href="https://use.fontawesome.com">\n  <link rel="preconnect" href="https://www.ncbi.nlm.nih.gov">\n  \n  <script src="https://use.fontawesome.com/20a31629ec.js"></script>\n<!--[if lte IE 7]>\n       <link href="/ct2/html/css/target-IE7-and-below.css" rel="stylesheet" type="text/css">\n<![endif]-->\n\n<style type="text/css">\n  h2 \n  {\n      background-color: #EAEAEA;\n  }\n</style>\n<link href="/ct2/html/css/trial-record.css?v=48" rel="stylesheet" type="text/css" />\r\n\r\n\t<script type="text/javascript" src="/ct2/html/jquery/js/jquery.min.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/jquery/js/superclick.min.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/js/ct.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/js/ctmenu.js?v=48"></script><noscript></noscript>\r\n<script>\r\nvar theURL = "/ct2/show/record/NCT05768113?map_cntry=US&map_state=US%3ANJ&draw=2&rank=1&view=record"+window.location.hash;\r\nhistory.replaceState(null,null,theURL);\r\n</script>\r\n\r\n  <meta name="ncbi_sid" content="4ec897c24186c596_4d4cfdSID"/>\n  <meta name ...

# %%
## psss payload: 25 ount -> Page count 
payload = {"page": 3 , 'count': 25}

# %%
pd.read_html(oururl.text, match="tr")[0].iloc[36:]
# Out:
#              Tracking Information  \
# 36           Eligibility Criteria
# 37                     Sex/Gender
# 38                           Ages
# 39     Accepts Healthy Volunteers
# 40                       Contacts
# 41      Listed Location Countries
# 42     Removed Location Countries
# 43                            NaN
# 44     Administrative Information
# 45                     NCT Number
# 46         Other Study ID Numbers
# 47  Has Data Monitoring Committee
# 48     U.S. FDA-regulated Product
# 49          IPD Sharing Statement
# 50      Current Responsible Party
# 51     Original Responsible Party
# 52          Current Study Sponsor
# 53         Original Study Sponsor
# 54                  Collaborators
# 55                  Investigators
# 56                    PRS Account
# 57              Verification Date
#
#                                Tracking Information.1
# 36  Inclusion Criteria:  Ability to provide writte...
# 37                     Sexes Eligible for Study:  All
# 38          18 Years to 65 Years (Adult, Older Adult)
# 39                                                 No
# 40  Contact information is only displayed when the...
# 41                                      United States
# 42                                                NaN
# 43                                                NaN
# 44                         Administrative Information
# 45                                        NCT05768113
# 46                                     SLV-CV19-SPRAY
# 47                                       Not Provided
# 48  Studies a U.S. FDA-regulated Drug Product: No ...
# 49                             Plan to Share IPD:  No
# 50                                 Salvacion USA Inc.
# 51                                    Same as current
# 52                                 Salvacion USA Inc.
# 53                                    Same as current
# 54                                       Not Provided
# 55  Principal Investigator:  Jorge Amaya P Amaya, ...
# 56                                 Salvacion USA Inc.
# 57                                       January 2023
