# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SearchResults.csv")

# %%
df.drop("Rank", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NCT Number               10000 non-null  object
#  1   Title                    10000 non-null  object
#  2   Acronym                  2619 non-null   object
#  3   Status                   10000 non-null  object
#  4   Study Results            10000 non-null  object
#  5   Conditions               10000 non-null  object
#  6   Interventions            9597 non-null   object
#  7   Outcome Measures         9540 non-null   object
#  8   Sponsor/Collaborators    10000 non-null  object
#  9   Gender                   9993 non-null   object
#  10  Age                      10000 non-null  object
#  11  Phases                   8838 non-null   object
#  12  Enrollment               9778 non-null   float64
#  13  Funded Bys               10000 non-null  object
#  14  Study Type               10000 non-null  object
#  15  Study Designs            9912 non-null   object
#  16  Other IDs                10000 non-null  object
#  17  Start Date               9819 non-null   object
#  18  Primary Completion Date  9502 non-null   object
#  19  Completion Date          9514 non-null   object
#  20  First Posted             10000 non-null  object
#  21  Results First Posted     3357 non-null   object
#  22  Last Update Posted       10000 non-null  object
#  23  Locations                10000 non-null  object
#  24  Study Documents          1729 non-null   object
#  25  URL                      10000 non-null  object
# dtypes: float64(1), object(25)
# memory usage: 2.0+ MB

# %% [markdown]
# # Missing Data
# - Handling Missing Data

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.drop("Acronym", axis=1, inplace=True)

# %% [markdown]
# ## Intervertentions
# - we can use other data features to replace the missing values
# - gender has Male, Female, All

# %%
gender = pd.get_dummies(df["Gender"], drop_first=True)

# %%
df = pd.concat([df, gender], axis=1)

# %%
sns.countplot(x = df["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df.drop("Gender", axis=1, inplace=True)

# %% [markdown]
# ## Study Doc
# - Dropping missing too many values

# %%
df.drop("Study Documents", axis=1, inplace=True)

# %%
df.drop("Results First Posted", axis=1, inplace=True)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["organization"] = df["Locations"].apply(lambda x : x.split(",")[0])

# %%
df["state"] = df["Locations"].apply(lambda x : x.split(",")[-2])

# %%
df.drop("Locations", axis=1, inplace=True)

# %% [markdown]
# ## Drpping NA for the time being

# %%
df = df.dropna(axis=0)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["Status"].unique()
# Out:
# array(['Recruiting', 'Not yet recruiting', 'Enrolling by invitation',
#        'Completed', 'Active, not recruiting', 'Terminated', 'Withdrawn',
#        'Suspended', 'Unknown status'], dtype=object)

# %%
lisyFOrStatue = list(enumerate(df["Status"].unique()))

# %%
statusINdex = [x[0] for x in lisyFOrStatue]

# %%
status = [x[1] for x in lisyFOrStatue]

# %%
statusDict = dict(list(zip(status, statusINdex)))

# %%
df["Status"] = df["Status"].apply(lambda x: statusDict[x])

# %%
df["Study Results"].nunique()
# Out:
# 2

# %%
df["Study Results"] = pd.get_dummies(df["Study Results"], drop_first=True)

# %% [markdown]
# ## AGe

# %%
df["Age"] = df["Age"].apply(lambda x : x.split(",")[0].split("(")[0])

# %%
df["Age"].nunique()
# Out:
# 543

# %%
df["Age"] = df["Age"].apply(lambda x : x.split("/")[0])

# %%
df["Age"].nunique()
# Out:
# 543

# %%
listOFAges = list(enumerate(df["Age"].unique()))

# %%
ageIndex = [x[0] for x in listOFAges]

# %%
age = [x[1] for x in listOFAges]

# %%
zippyAge = dict(zip(age, ageIndex))

# %%
df["Age"] = df["Age"].apply(lambda x : zippyAge[x])

# %%
phases = pd.get_dummies(df["Phases"], drop_first=True)

# %%
df = pd.concat([df, phases], axis=1)

# %%
df.drop("Phases", axis=1, inplace=True)

# %%
df["Sponsor/Collaborators"].nunique()
# Out:
# 2843

# %%
spoandcolab = list(enumerate(df["Sponsor/Collaborators"].unique()))

# %%
spoINdex = [x[0] for x in spoandcolab]

# %%
spo = [x[1] for x in spoandcolab]

# %%
spoDict = dict(zip(spo, spoINdex))

# %%
df["Sponsor/Collaborators"] = df["Sponsor/Collaborators"].apply(lambda x : spoDict[x])

# %%
df.columns
# Out:
# Index(['NCT Number', 'Title', 'Status', 'Study Results', 'Conditions',
#        'Interventions', 'Outcome Measures', 'Sponsor/Collaborators', 'Age',
#        'Enrollment', 'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs',
#        'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Last Update Posted', 'URL', 'Female', 'Male',
#        'organization', 'state', 'Not Applicable', 'Phase 1', 'Phase 1|Phase 2',
#        'Phase 2', 'Phase 2|Phase 3', 'Phase 3', 'Phase 4'],
#       dtype='object')

# %%
df.drop("Outcome Measures", axis = 1,  inplace=True)

# %%
df["Conditions"] = df["Conditions"].apply(lambda x : x.split("|")[0])

# %%
condList = list(enumerate(df["Conditions"].unique()))

# %%
condIndex = [x[0] for x in condList]

# %%
cond = [x[1] for x in condList]

# %%
conDict = dict(zip(cond, condIndex))

# %%
df["Conditions"] = df["Conditions"].apply(lambda x: conDict[x])

# %%
df["Interventions"] = df["Interventions"].apply(lambda x:x.split(":")[0])

# %%
df["Interventions"].nunique()
# Out:
# 11

# %%
interventionList = list(enumerate(df["Interventions"].unique()))

# %%
interIndex = [x[0] for x in interventionList]

# %%
interv = [x[1] for x in interventionList]

# %%
interDict = dict(zip(interv, interIndex))

# %%
df["Interventions"] = df["Interventions"].apply(lambda x : interDict[x])

# %%
df.drop(["Title","NCT Number"], axis=1, inplace=True)

# %%
df["Funded Bys"].nunique()
# Out:
# 29

# %%
fundedLit = list(enumerate(df["Funded Bys"].unique()))

# %%
fundedUndex = [x[0] for x in fundedLit]

# %%
funded = [x[1] for x in fundedLit]

# %%
fundedDict = dict(zip(funded, fundedUndex))

# %%
df["Funded Bys"] = df["Funded Bys"].apply(lambda x: fundedDict[x])

# %% [markdown]
# ## Drop only one type

# %%
df["Study Type"]
# Out:
# 1       Interventional
# 2       Interventional
# 3       Interventional
# 5       Interventional
# 7       Interventional
#              ...
# 9995    Interventional
# 9996    Interventional
# 9997    Interventional
# 9998    Interventional
# 9999    Interventional
# Name: Study Type, Length: 8065, dtype: object

# %%
df["Study Type"].nunique()
# Out:
# 1

# %%
df.drop("Study Type", axis=1, inplace=True)

# %%
df["Allocation"] = df["Study Designs"].apply(lambda x : x.split("|")[0].split(":")[1])

# %%
df["Allocation"].nunique()
# Out:
# 11

# %%
alloList = list(enumerate(df["Allocation"].unique()))

# %%
alloIndex = [x[0] for x in alloList]

# %%
allo = [x[1] for x in alloList]

# %%
alloDict = dict(zip(allo, alloIndex))

# %%
df["Allocation"] = df["Allocation"].apply(lambda x: alloDict[x])

# %%
df.drop("Study Designs", axis=1, inplace=True)

# %%
df.drop("Other IDs", axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['Status', 'Study Results', 'Conditions', 'Interventions',
#        'Sponsor/Collaborators', 'Age', 'Enrollment', 'Funded Bys',
#        'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Last Update Posted', 'URL', 'Female', 'Male',
#        'organization', 'state', 'Not Applicable', 'Phase 1', 'Phase 1|Phase 2',
#        'Phase 2', 'Phase 2|Phase 3', 'Phase 3', 'Phase 4', 'Allocation'],
#       dtype='object')

# %% [markdown]
# ## Dropping URL

# %%
df.drop("URL", axis=1, inplace=True)

# %% [markdown]
# ## Dates

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df["Start day"] = [x.day for x in df["Start Date"]]

# %%
df["Start month"] = [x.month for x in df["Start Date"]]

# %%
df["Start year"] = [x.year for x in df["Start Date"]]

# %%
df.drop("Start Date", axis=1, inplace=True)

# %%
df["Primary Completion Date"] = pd.to_datetime(df["Primary Completion Date"])

# %%
df["Primary Completion Day"] = [x.day for x in df["Primary Completion Date"]]

# %%
df["Primary Completion month"] = [x.month for x in df["Primary Completion Date"]]

# %%
df["Primary Completion year"] = [x.year for x in df["Primary Completion Date"]]

# %%
df.drop("Primary Completion Date", axis=1, inplace=True)

# %%
df["Completion Date"] = pd.to_datetime(df["Completion Date"])

# %%
df["Completion Day"] = [x.day for x in df["Completion Date"]]

# %%
df["Completion Month"] = [x.month for x in df["Completion Date"]]

# %%
df["Completion year"] = [x.year for x in df["Completion Date"]]

# %%
df.drop("Completion Date", axis=1, inplace=True)

# %%
df["First Posted"] = pd.to_datetime(df["First Posted"])

# %%
df["First Posted Day"] = [x.day for x in df["First Posted"]]

# %%
df["First Posted Month"] = [x.month for x in df["First Posted"]]

# %%
df["First Posted year"] = [x.year for x in df["First Posted"]]

# %%
df.drop("First Posted", axis=1, inplace=True)

# %%
df["Last Update Posted"] = pd.to_datetime(df["Last Update Posted"])

# %%
df["Last Update Posted Day"] = [x.day for x in df["Last Update Posted"]]

# %%
df["Last Update Posted Month"] = [x.month for x in df["Last Update Posted"]]

# %%
df["Last Update Posted Year"] = [x.year for x in df["Last Update Posted"]]

# %%
df.drop("Last Update Posted", axis=1, inplace=True)

# %% [markdown]
# ## Org and state

# %%
df["organization"].nunique()
# Out:
# 3187

# %%
orgList = list(enumerate(df["organization"].unique()))

# %%
orgIndex = [x[0] for x in orgList]

# %%
org = [x[1] for x in orgList]

# %%
orgDict = dict(zip(org, orgIndex))

# %%
df["organization"] = df["organization"].apply(lambda x : orgDict[x])

# %%
statList = list(enumerate(df["state"].unique()))

# %%
stateIndex = [x[0] for x in statList]

# %%
state = [x[1] for x in statList]

# %%
stateDict = dict(zip(state, spoINdex))

# %%
df["state"] = df["state"].apply(lambda x: stateDict[x])

# %%
df.corrwith(df["Status"]).sort_values().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.corr(), annot=True,cbar=False, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Creation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.metrics import confusion_matrix, classification_report, explained_variance_score

# %%
X = df.drop("Status", axis=1).values
y = df["Status"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense

# %%
scalar = MinMaxScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
X_train.shape
# Out:
# (5645, 34)

# %%
model = Sequential()
model.add(Dense(units=120, activation="relu"))
model.add(Dense(units=120, activation="relu"))

model.add(Dense(units=1, activation="sigmoid"))

model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
stop = EarlyStopping(patience=150)

# %%
model.fit(X_train, y_train, epochs = 600, validation_data = (X_test, y_test), callbacks = [stop] )
# Out:
# 2023-03-31 04:13:19.732780: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 04:13:19.733764: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 10. Tune using inter_op_parallelism_threads for best performance.
# Train on 5645 samples, validate on 2420 samples
# Epoch 1/600
# 5645/5645 [==============================] - 2s 374us/sample - loss: -912.6737 - accuracy: 0.0092 - val_loss: -4258.1525 - val_accuracy: 0.0058
# Epoch 2/600
# 5645/5645 [==============================] - 1s 190us/sample - loss: -19785.8957 - accuracy: 0.0076 - val_loss: -44979.1010 - val_accuracy: 0.0058
# Epoch 3/600
# 5645/5645 [==============================] - 1s 192us/sample - loss: -96095.9409 - accuracy: 0.0076 - val_loss: -162275.6993 - val_accuracy: 0.0058
# Epoch 4/600
# 5645/5645 [==============================] - 1s 208us/sample - loss: -266306.7053 - accuracy: 0.0076 - val_loss: -388134.4206 - val_accuracy: 0.0058
# Epoch 5/600
# 5645/5645 [==============================] - 1s 188us/sample - loss: -559257.5201 - accuracy: 0.0076 - val_loss: -748613.7457 - val_accuracy: 0.0058
# Epoch 6/600
# 5645/5645 [==============================] - 1s 203us/sample - loss: -998421.6278 - accuracy: 0.0076 - val_loss: -1264813.8589 - val_accuracy: 0.0058
# Epoch 7/600
# 5184/5645 [==========================>...] - ETA: 0s - loss: -1581258.9491 - accuracy: 0.0081WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/44/4288ncqn6p3cxnm99z8rvcl80000gp/T/ipykernel_87726/4175246917.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs = 600, validation_data = (X_test, y_test), callbacks = [stop] )
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
longUrl = "https://clinicaltrials.gov/ct2/show/record/NCT05766254?map_cntry=US&map_state=US%3ANJ&draw=2&rank=1"

# %%
shortURL = "https://clinicaltrials.gov/ct2/show/record/NCT05755061"

# %%
#### import json
import requests

from bs4 import BeautifulSoup

URL = (shortURL)
oururl= requests.get(URL, "r")

# %%
oururl.text
# Out:
# '\r\n\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml" lang=\'en\'>\n<head>  \n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    <meta name="robots" content="noindex,nofollow"/>\n    <meta name="referrer" content="origin-when-cross-origin"/>\n  <title>WEBCAMS: Walking Exercise for Brain and Cognition in Adults With Multiple Sclerosis - Tabular View - ClinicalTrials.gov</title>\n    <link href="/ct2/show/record/NCT05755061" rel="canonical"/>\n    \n  <!-- Twitter Card data -->\n  <meta name="twitter:card" content="summary">\n  <meta name="twitter:image" content="https://clinicaltrials.gov/ct2/html/images/ct.gov-nlm-nih-square-logo.png?v1">\n\n  <!-- Open Graph data -->\n  <meta property="og:type" content="article" />\n  <meta property="og:title" content="WEBCAMS: Walking Exercise for Brain and Cognition in Adults With Multiple Sclerosis - Tabular View - ClinicalTrials.gov">\n  <meta property="og:image" content="https://clinicaltrials.gov/ct2/html/images/ct.gov-nlm-nih-square-logo.png?v1">\n    <meta property="og:description" content="WEBCAMS: Walking Exercise for Brain and Cognition in Adults With Multiple Sclerosis - Tabular View.">\n  <meta property="og:url" content="https://clinicaltrials.gov/ct2/show/record/NCT05755061">\n    \n  <link rel="shortcut icon" href="/ct2/html/images/favicon.ico" />\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-144x144.png\' sizes=\'144x144\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-114x114.png\' sizes=\'114x114\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-72x72.png\'   sizes=\'72x72\'>\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon-precomposed.png\' >\n  <link rel=\'apple-touch-icon-precomposed\' href=\'/ct2/html/images/apple-touch-icon.png\' >\n\n  <link rel="stylesheet" type="text/css" href="/ct2/html/jquery/css/superfish.css?v=48" media="screen" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/jquery/css/superfish-vertical.css?v=48" media="screen" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/glossary.css?v=48" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/base.css?v=48" />\n  <link rel="stylesheet" type="text/css" href="/ct2/html/css/print.css?v=48" media="print" />\n  <link rel="stylesheet" href="/ct2/html/css/w3-ct.css?v=48" type="text/css" />\n  <!--[if lt IE 9]>\n\t<link rel="stylesheet" href="/ct2/html/css/w3-ct-oldIE.css?v=48" type="text/css" />\n  <![endif]-->\n   \t\n  <link rel="preconnect" href="https://use.fontawesome.com">\n  <link rel="preconnect" href="https://www.ncbi.nlm.nih.gov">\n  \n  <script src="https://use.fontawesome.com/20a31629ec.js"></script>\n<!--[if lte IE 7]>\n       <link href="/ct2/html/css/target-IE7-and-below.css" rel="stylesheet" type="text/css">\n<![endif]-->\n\n<style type="text/css">\n  h2 \n  {\n      background-color: #EAEAEA;\n  }\n</style>\n<link href="/ct2/html/css/trial-record.css?v=48" rel="stylesheet" type="text/css" />\r\n\r\n\t<script type="text/javascript" src="/ct2/html/jquery/js/jquery.min.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/jquery/js/superclick.min.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/js/ct.js?v=48"></script><noscript></noscript>\n<script type="text/javascript" async src="/ct2/html/js/ctmenu.js?v=48"></script><noscript></noscript>\r\n<script>\r\nvar theURL = "/ct2/show/record/NCT05755061?view=record"+window.location.hash;\r\nhistory.replaceState(null,null,theURL);\r\n</script>\r\n\r\n  <meta name="ncbi_ ...

# %%
## psss payload: 25 ount -> Page count 
payload = {"page": 3 , 'count': 25}

# %%
pd.read_html(oururl.text, match="tr")[0].iloc[36:]
# Out:
#                                  Tracking Information  \
# 36                   Accepts Healthy Volunteers ICMJE
# 37                                     Contacts ICMJE
# 38                    Listed Location Countries ICMJE
# 39                         Removed Location Countries
# 40                                                NaN
# 41                         Administrative Information
# 42                                   NCT Number ICMJE
# 43                       Other Study ID Numbers ICMJE
# 44                      Has Data Monitoring Committee
# 45                         U.S. FDA-regulated Product
# 46                        IPD Sharing Statement ICMJE
# 47                          Current Responsible Party
# 48                         Original Responsible Party
# 49                        Current Study Sponsor ICMJE
# 50                       Original Study Sponsor ICMJE
# 51                                Collaborators ICMJE
# 52                                Investigators ICMJE
# 53                                        PRS Account
# 54                                  Verification Date
# 55  ICMJE Data element required by the  Internatio...
#
#                                Tracking Information.1
# 36                                                 No
# 37  Contact: Brian M Sandroff, PhD  973.965.6649  ...
# 38                                      United States
# 39                                                NaN
# 40                                                NaN
# 41                         Administrative Information
# 42                                        NCT05755061
# 43                                          R-1194-22
# 44                                                 No
# 45  Studies a U.S. FDA-regulated Drug Product: No ...
# 46                      Plan to Share IPD:  Undecided
# 47                 Brian Sandroff, Kessler Foundation
# 48                                    Same as current
# 49                                 Kessler Foundation
# 50                                    Same as current
# 51                                       Not Provided
# 52                                       Not Provided
# 53                                 Kessler Foundation
# 54                                      February 2023
# 55  ICMJE Data element required by the  Internatio...

# %%
print(pd.read_html(oururl.text,
             match="tr")[0].set_index("Tracking Information").loc["Eligibility Criteria ICMJE"].values)
# Out:
# ['Inclusion Criteria:  Definite MS diagnosis  Relapse-free for at least 30 days  Have Internet access on a device larger than a smartphone  Willingness and ability to travel to Kessler Foundation 3 times over a 12-month period  Be insufficiently physically active  Demonstrate low fall risk based on Activities Specific Balance Confidence scores  Demonstrate low contraindications for exercise  Right handedness  English as a primary language  Demonstrate low cognitive processing speed based on a Zoom-administered Symbol Digit Modalities Test  Exclusion Criteria:  Acutely taken corticosteroids within 30 days of enrollment  Use an assistive device (i.e., cane, crutch, walker, rollator) for ambulation  Experienced a fall in the past 6 months  Have uncontrolled major depressive disorder or history of bipolar disorder or schizophrenia  Regularly taking medications that can affect cognition (e.g., antipsychotics, benzodiazepines)  Demonstrate contraindications for 3T MRI (i.e., having metal/shrapnel in the body, non-MRI compatible aneurysm clips)  Have severe cognitive impairment causing an inability to follow directions']

# %% [markdown]
# ## Getting All NCT numbers

# %%
nct_Numnbers = list(df["NCT Number"])

# %% [markdown]
# ## Generating the URls For each study
# - eg https://clinicaltrials.gov/ct2/show/record/NCT05755061

# %%
recordUrls = [f"https://clinicaltrials.gov/ct2/show/record/{x}" for x in nct_Numnbers]

# %% [markdown]
# ## Getting the Elegibility Criteria (inclusitn and Exclusion

# %% [markdown]
# ##### Fetching HTML responses from each trial (10,000 at the moment)

# %%
import requests
urlResponses = []
for url in recordUrls:
    URL = (url)
    urlResponses.append(requests.get(URL, "r"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/44/4288ncqn6p3cxnm99z8rvcl80000gp/T/ipykernel_87726/1195296664.py in <module>
#       3 for url in recordUrls:
#       4     URL = (url)
# ----> 5     urlResponses.append(requests.get(URL, "r"))
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     622         """
#     623         if self.chunked and self.supports_chunked_reads():
# --> 624             for line in self.read_chunked(amt, decode_content=decode_content):
#     625                 yield line
#     626         else:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     826
#     827             while True:
# --> 828                 self._update_chunk_length()
#     829                 if self.chunk_left == 0:
#     830                     break
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     756         if self.chunk_left is not None:
#     757             return
# --> 758         line = self._fp.fp.readline()
#     759         line = line.split(b";", 1)[0]
#     760         try:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/tf2/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
pd.read_html(oururl.text, match="ClinicalTrials.gov Identifier")[0].iloc[0].apply(lambda x : x.split(" ")[-1])[0]
# Out:
# 'NCT05766254'

# %%
df = pd.read_csv("SearchResults.csv")

# %%
df
# Out:
#        Rank   NCT Number                                              Title  \
# 0         1  NCT05768113  LAEH Formulation Nasal Spray to Reduce Viral Load
# 1         2  NCT05766254  Identify the Optimal TMS Target to Modulate Re...
# 2         3  NCT05760573       The Ready and Healthy for Kindergarten Study
# 3         4  NCT05755061  WEBCAMS: Walking Exercise for Brain and Cognit...
# 4         5  NCT05734521               Avalglucosidase Alfa Pregnancy Study
# ...     ...          ...                                                ...
# 9995   9996  NCT02224781  Dabrafenib and Trametinib Followed by Ipilimum...
# 9996   9997  NCT02224755             MOMENTUM 3 IDE Clinical Study Protocol
# 9997   9998  NCT02224664  Safety, Tolerability, Pharmacokinetics and Pha...
# 9998   9999  NCT02223039  A Study of Multiple Doses of AbGn-168H by Intr...
# 9999  10000  NCT02222493  A Study of PF-06438179 (Infliximab-Pfizer) and...
#
#      Acronym                  Status         Study Results  \
# 0        NaN               Completed  No Results Available
# 1        NaN              Recruiting  No Results Available
# 2        NaN      Not yet recruiting  No Results Available
# 3        NaN              Recruiting  No Results Available
# 4        NaN              Recruiting  No Results Available
# ...      ...                     ...                   ...
# 9995     NaN  Active, not recruiting  No Results Available
# 9996    HM3™               Completed           Has Results
# 9997     NaN               Completed           Has Results
# 9998     NaN               Completed  No Results Available
# 9999     NaN               Completed           Has Results
#
#                                              Conditions  \
# 0                                   Coronavirus Disease
# 1                                 Nicotine Use Disorder
# 2     Parenting|Language Development|Literacy|Health...
# 3     Multiple Sclerosis|Relapsing-remitting Multipl...
# 4                               Pompe Disease|Pregnancy
# ...                                                 ...
# 9995  Clinical Stage III Cutaneous Melanoma AJCC v8|...
# 9996  Advanced Refractory Left Ventricular Heart Fai...
# 9997                                Parkinson's Disease
# 9998        Moderate to Severe Chronic Plaque Psoriasis
# 9999                               Rheumatoid Arthritis
#
#                                           Interventions  \
# 0                                                   NaN
# 1     Device: Active 10-Hz TMS to the DLPFC|Device: ...
# 2             Behavioral: Family Wellness Program (FWP)
# 3                Behavioral: GEMS Plus|Behavioral: GEMS
# 4     Biological: avalglucosidase alfa-NGPT (GZ40266...
# ...                                                 ...
# 9995  Procedure: Biospecimen Collection|Procedure: C...
# 9996  Device: HeartMate 3 LVAS|Device: HeartMate II ...
# 9997                                  Drug: PF-06649751
# 9998          Biological: AbGn-168H|Biological: Placebo
# 9999     Biological: PF-06438179|Biological: Infliximab
#
#                                        Outcome Measures  \
# 0             Enumerating viral load using RT-PCR test.
# 1     Event-related Brain Potential: Reward Positivi...
# 2     Home Literacy Environment Questionnaire|Parent...
# 3     Change in cognitive processing speed|Change in...
# 4     Maternal complications|Pregnancy outcome|Infan...
# ...                                                 ...
# 9995  Overall survival (OS) rate|Progression-free su...
# 9996  Short Term Primary End Point|Long Term Primary...
# 9997  Number of Participants With Treatment-Emergent...
# 9998  75% reduction in the Psoriasis Area Severity I...
# 9999  Number of Participants With an American Colleg...
#
#                                   Sponsor/Collaborators  ...  \
# 0                                    Salvacion USA Inc.  ...
# 1           Rutgers, The State University of New Jersey  ...
# 2     Rutgers, The State University of New Jersey|Ag...  ...
# 3                                    Kessler Foundation  ...
# 4                                                Sanofi  ...
# ...                                                 ...  ...
# 9995                    National Cancer Institute (NCI)  ...
# 9996        Abbott Medical Devices|Thoratec Corporation  ...
# 9997                                             Pfizer  ...
# 9998                       AbGenomics B.V Taiwan Branch  ...
# 9999                                             Pfizer  ...
#
#                                         Other IDs         Start Date  \
# 0                                  SLV-CV19-SPRAY       May 29, 2021
# 1                                   Pro2022000444         March 2023
# 2                     Pro2021001575-2|R18HS028574         March 2023
# 3                                       R-1194-22   February 1, 2023
# 4                                        OBS17641   October 26, 2022
# ...                                           ...                ...
# 9995            NCI-2014-01747|EA6134|U10CA180820      July 13, 2015
# 9996                                   TC03062014  September 2, 2014
# 9997                      B7601005|2014-003472-22       October 2014
# 9998                                  2014.002.01           May 2014
# 9999  B5371002|REFLECTIONS B537-02|2013-004148-49    August 26, 2014
#
#      Primary Completion Date  Completion Date       First Posted  \
# 0            October 4, 2021  January 6, 2022     March 14, 2023
# 1             September 2024   September 2024     March 13, 2023
# 2              June 30, 2026  August 30, 2026      March 8, 2023
# 3               May 31, 2024    July 31, 2024      March 6, 2023
# 4               October 2032     October 2032  February 21, 2023
# ...                      ...              ...                ...
# 9995         October 2, 2023  October 2, 2023    August 25, 2014
# 9996      September 28, 2018   March 26, 2019    August 25, 2014
# 9997              March 2016       March 2016    August 25, 2014
# 9998           December 2014    February 2015    August 22, 2014
# 9999           June 29, 2016     June 1, 2017    August 21, 2014
#
#      Results First Posted Last Update Posted  \
# 0                     NaN     March 14, 2023
# 1                     NaN     March 13, 2023
# 2                     NaN      March 8, 2023
# 3                     NaN      March 6, 2023
# 4                     NaN  February 21, 2023
# ...                   ...                ...
# 9995                  NaN     March 10, 2023
# 9996    November 20, 2019      June 27, 2022
# 9997       March 27, 2017     March 27, 2017
# 9998                  NaN     April 14, 2016
# 9999   September 11, 2017       May 30, 2018
#
#                                               Locations  \
# 0     Global Clinical Trials, LLC,, Princeton, New J...
# 1     Rutgers University - Newark, Newark, New Jerse...
# 2     Child Health Institute, New Brunswick, New Jer...
# 3     Kessler Foundation, West Orange, New Jersey, U...
# 4     Investigational site worldwide, Bridgewater, N...
# ...                                                 ...
# 9995  University of Alabama at Birmingham Cancer Cen...
# 9996  Baptist Health Medical Center - Little Rock, L...
# 9997  Orange Coast Memorial Medical Center, Fountain...
# 9998  Alliance Dermatology & MOHS Center, PC, Phoeni...
# 9999  Achieve Clinical Research, LLC, Birmingham, Al...
#
#                                         Study Documents  \
# 0     "Study Protocol and Statistical Analysis Plan"...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996  "Study Protocol", https://ClinicalTrials.gov/P...
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                               URL
# 0     https://ClinicalTrials.gov/show/NCT05768113
# 1     https://ClinicalTrials.gov/show/NCT05766254
# 2     https://ClinicalTrials.gov/show/NCT05760573
# 3     https://ClinicalTrials.gov/show/NCT05755061
# 4     https://ClinicalTrials.gov/show/NCT05734521
# ...                                           ...
# 9995  https://ClinicalTrials.gov/show/NCT02224781
# 9996  https://ClinicalTrials.gov/show/NCT02224755
# 9997  https://ClinicalTrials.gov/show/NCT02224664
# 9998  https://ClinicalTrials.gov/show/NCT02223039
# 9999  https://ClinicalTrials.gov/show/NCT02222493
#
# [10000 rows x 27 columns]
